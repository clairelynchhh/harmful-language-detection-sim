# %%
# CSC396 - Intro to Deep Learning w/ NLP
# Claire Lynch & Jose Santiago Campa Morales
# Final Project
# Hate Speech and Offensive Language Classifier

import pandas as pd

# %%
# Load dataset
file_path = "data/labeled_data.csv"
df = pd.read_csv(file_path)

print("Shape:", df.shape)
print(df.head(10))
# Out:
# Shape: (24783, 7)
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
# 5           5      3            1                   2        0      1
# 6           6      3            0                   3        0      1
# 7           7      3            0                   3        0      1
# 8           8      3            0                   3        0      1
# 9           9      3            1                   2        0      1
#
#                                                                                                                                                             tweet
# 0                    !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...
# 1                                                                           !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!
# 2                                        !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit
# 3                                                                                                  !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny
# 4                       !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;
# 5  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just blows me..claim you so faithful and down for somebody but still fucking with hoes! &#128514;&#128514;&#128514;"
# 6                                                       !!!!!!"@__BrighterDays: I can not just sit up and HATE on another bitch .. I got too much shit going on!"
# 7                                                              !!!!&#8220;@selfiequeenbri: cause I'm tired of you big bitches coming for us skinny girls!!&#8221;
# 8                                                                                                      " &amp; you might not get ya bitch back &amp; thats that "
# 9                                                                                                       " @rhythmixx_ :hobbies include: fighting Mariam"\n\nbitch

# %%
# Only use tweet and class columns
# Original: # [count, hate_speech, offensive_language, neither, class, tweet]
df = df[['tweet', 'class']].copy()

# Map classes to labels
label_map = {
    0: "hate_speech",
    1: "offensive_language",
    2: "neither"
}

df['label'] = df['class'].map(label_map)

# %%
# Samples
print("\nSample tweets:")
print(df.sample(10))
# Out:
# Sample tweets:
#                                                                                                                                               tweet  \
# 8275       Bytch was an infant... &#171;@Mr_JSmart24 How the hell this bitch 18 talking bout how much she remember bout Pac before he died!?!&#187;
# 15076                                                       RT @Dunky_hoeless55: You a hoe if you leaving a man's house right now with a costume on
# 22024                                  This car has two registration tags. Both yellow. One for 2014 &amp; one for 2005. Wth http://t.co/mdeD4a2soY
# 8413                                                  Charles was eatin trash ass Dominoes in that pic...you know he was still poor at the time lol
# 7969                                                        Because I had to accept being called a bitch every time I asserted myself. #YesAllWomen
# 24534  there was a bird on the back balcony, dead. with sadness I reflected on the fragility of life, put him in a bag, and threw him in the trash.
# 20916                           Smuggled letter by Gaza tunnel digger details suffering under Hamas rule http://t.co/jusiee1yhK via @TheMuslimIssue
# 21841                           These parents nd giving they kids ghetto ass names Ronkieshietta. Bro are you serious?? That tipped the scale fa me
# 7203        @triple6em96 @longbongchris stfu you stupid bitch? Like leave us alone? No one gives a fuck about you. Bruh just block her. We're good.
# 21815                                                                              These hoes want love so bad &#128514;&#128514;&#128078;&#128581;
#
#        class               label
# 8275       1  offensive_language
# 15076      1  offensive_language
# 22024      2             neither
# 8413       1  offensive_language
# 7969       1  offensive_language
# 24534      2             neither
# 20916      2             neither
# 21841      1  offensive_language
# 7203       1  offensive_language
# 21815      1  offensive_language

# %%
# Basic Stats
print("\nLabel distribution:")
print(df['label'].value_counts())
# Out:
# Label distribution:
# label
# offensive_language    19190
# neither                4163
# hate_speech            1430
# Name: count, dtype: int64
